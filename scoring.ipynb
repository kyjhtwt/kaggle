# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout
import os
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import tensorflow.keras.layers as layers
import yaml
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from tensorflow.python.keras.models import load_model

# %%
with open('config.yml') as file:
    config = yaml.load(file, Loader=yaml.FullLoader)
model_name = config['system']['model_name']

# %%
test_df = pd.read_excel('test.xlsx')

# %%
test_df
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare  Infant  family
# 0            892       3    male  34.5      0      0    7.8292       0       0
# 1            893       3  female  47.0      1      0    7.0000       0       1
# 2            894       2    male  62.0      0      0    9.6875       0       0
# 3            895       3    male  27.0      0      0    8.6625       0       0
# 4            896       3  female  22.0      1      1   12.2875       0       2
# ..           ...     ...     ...   ...    ...    ...       ...     ...     ...
# 413         1305       3    male  30.0      0      0    8.0500       0       0
# 414         1306       1  female  39.0      0      0  108.9000       0       0
# 415         1307       3    male  38.5      0      0    7.2500       0       0
# 416         1308       3    male  30.0      0      0    8.0500       0       0
# 417         1309       3    male  30.0      1      1   22.3583       0       2
#
# [418 rows x 9 columns]

# %%
model = load_model(model_name)

# %%
y_pred = model.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/data/util/structure.py in normalize_element(element, element_signature)
#     101         if spec is None:
# --> 102           spec = type_spec_from_value(t, use_fallback=False)
#     103       except TypeError:
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/data/util/structure.py in type_spec_from_value(element, use_fallback)
#     486       element,
# --> 487       type(element).__name__))
#     488
#
# TypeError: Could not build a `TypeSpec` for      PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare  Infant  family
# 0            892       3    male  34.5      0      0    7.8292       0       0
# 1            893       3  female  47.0      1      0    7.0000       0       1
# 2            894       2    male  62.0      0      0    9.6875       0       0
# 3            895       3    male  27.0      0      0    8.6625       0       0
# 4            896       3  female  22.0      1      1   12.2875       0       2
# ..           ...     ...     ...   ...    ...    ...       ...     ...     ...
# 413         1305       3    male  30.0      0      0    8.0500       0       0
# 414         1306       1  female  39.0      0      0  108.9000       0       0
# 415         1307       3    male  38.5      0      0    7.2500       0       0
# 416         1308       3    male  30.0      0      0    8.0500       0       0
# 417         1309       3    male  30.0      1      1   22.3583       0       2
#
# [418 rows x 9 columns] with type DataFrame
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/qw/tb6y5lcn683fs1xbng0p5xyc0000gp/T/ipykernel_63368/1389619457.py in <module>
# ----> 1 y_pred = model.predict(test_df)
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1720           use_multiprocessing=use_multiprocessing,
#    1721           model=self,
# -> 1722           steps_per_execution=self._steps_per_execution)
#    1723
#    1724       # Container that configures and calls `tf.keras.Callback`s.
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1392   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1393     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1394   return DataHandler(*args, **kwargs)
#    1395
#    1396
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1159         use_multiprocessing=use_multiprocessing,
#    1160         distribution_strategy=ds_context.get_strategy(),
# -> 1161         model=model)
#    1162
#    1163     strategy = ds_context.get_strategy()
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     333     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     334
# --> 335     dataset = self.slice_inputs(indices_dataset, inputs)
#     336
#     337     if shuffle == "batch":
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     359     dataset = dataset_ops.DatasetV2.zip((
#     360         indices_dataset,
# --> 361         dataset_ops.DatasetV2.from_tensors(inputs).repeat()
#     362     ))
#     363
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensors(tensors, name)
#     727       Dataset: A `Dataset`.
#     728     """
# --> 729     return TensorDataset(tensors, name=name)
#     730
#     731   @staticmethod
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, element, name)
#    4529   def __init__(self, element, name=None):
#    4530     """See `Dataset.from_tensors()` for details."""
# -> 4531     element = structure.normalize_element(element)
#    4532     self._structure = structure.type_spec_from_value(element)
#    4533     self._tensors = structure.to_tensor_list(self._structure, element)
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/data/util/structure.py in normalize_element(element, element_signature)
#     105         # the value. As a fallback try converting the value to a tensor.
#     106         normalized_components.append(
# --> 107             ops.convert_to_tensor(t, name="component_%d" % i))
#     108       else:
#     109         if isinstance(spec, sparse_tensor.SparseTensorSpec):
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1638
#    1639     if ret is None:
# -> 1640       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1641
#    1642     if ret is NotImplemented:
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#     344
#     345
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     266   """
#     267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 268                         allow_broadcast=True)
#     269
#     270
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277       with trace.Trace("tf.constant"):
#     278         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     280
#     281   g = ops.get_default_graph()
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type int).

# %%
y_pred = (y_pred > 0.5) * 1
submission = pd.DataFrame({"PassengerId": test_df['PassengerId'], "Survived":np.reshape(y_pred, len(y_pred))})
submission.to_csv('submission.csv', index=False)
