# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout
import os
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import tensorflow.keras.layers as layers
import yaml
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %%
with open('config.yml') as file:
    config = yaml.load(file, Loader=yaml.FullLoader)
    print(config)
BATCH_SIZE = config['learning']['BATCH_SIZE']
LEARNING_RATE = config['learning']['LEARNING_RATE']
DROP_OUT_RATE = config['learning']['DROP_OUT_RATE']
EPOCHS = config['learning']['EPOCHS']
# Out:
# {'learning': {'BATCH_SIZE': 1, 'LEARNING_RATE': 0.001, 'DROP_OUT_RATE': 0.5, 'EPOCHS': 100}, 'system': {'test': True, 'model_name': 'ann_plus_model.h5'}}

# %%
df = pd.read_excel('preprocessing.xlsx')
df
# Out:
#      Survived   Age     Fare  age_range  family  is_one_Parch  is_one_SibSp  \
# 0           0  22.0   7.2500          3       1             0             1
# 1           1  38.0  71.2833          3       1             0             1
# 2           1  26.0   7.9250          3       0             0             0
# 3           1  35.0  53.1000          3       1             0             1
# 4           0  35.0   8.0500          3       0             0             0
# ..        ...   ...      ...        ...     ...           ...           ...
# 886         0  27.0  13.0000          3       0             0             0
# 887         1  19.0  30.0000          2       0             0             0
# 888         0  30.0  23.4500          3       3             0             1
# 889         1  26.0  30.0000          3       0             0             0
# 890         0  32.0   7.7500          3       0             0             0
#
#      Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0             0         1           0           0           1
# 1             1         0           1           0           0
# 2             1         0           0           0           1
# 3             1         0           0           0           1
# 4             0         1           0           0           1
# ..          ...       ...         ...         ...         ...
# 886           0         1           0           0           1
# 887           1         0           0           0           1
# 888           1         0           0           0           1
# 889           0         1           1           0           0
# 890           0         1           0           1           0
#
# [891 rows x 12 columns]

# %%
# # categorical columns encoding
# categorical_columns = ['Pclass', 'Sex']
# for col in categorical_columns:
#     le = preprocessing.LabelEncoder()
#     le.fit(df[col].values)
#     df[col] = le.transform(df[col].values)

# %%
# train, test, validation data split
train, test = train_test_split(df, test_size=0.2)
train, val = train_test_split(train, test_size=0.2)

# %%
# pop label
y_train = train.pop('Survived')
y_test = test.pop('Survived')
y_val = val.pop('Survived')

# %%
early_terminator = EarlyStopping(monitor='val_accuracy', mode='max', patience=3, min_delta=0.001)
model_check = ModelCheckpoint('ann_plus_model.h5', save_best_only=True)

# %%
def ANN(optimizer):
    ann = Sequential()
    ann.add(Dense(units=32, kernel_initializer='glorot_uniform', activation='relu'))
    ann.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu'))
    ann.add(Dropout(rate=DROP_OUT_RATE))
    ann.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu'))
    ann.add(Dropout(rate=DROP_OUT_RATE))
    ann.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))
    ann.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return ann

# %%
opt = tf.optimizers.Adam(lr=0.001)
model = ANN(opt)
history = model.fit(train, y_train, batch_size=BATCH_SIZE, validation_data=(val, y_val), epochs=EPOCHS, callbacks=[model_check, ])
# Out:
# Epoch 1/100
# /opt/anaconda3/envs/test/lib/python3.7/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 569/569 [==============================] - 2s 2ms/step - loss: 1.7276 - accuracy: 0.5712 - val_loss: 0.7776 - val_accuracy: 0.6294
# Epoch 2/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.8090 - accuracy: 0.6344 - val_loss: 0.6892 - val_accuracy: 0.6923
# Epoch 3/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.6823 - accuracy: 0.6538 - val_loss: 0.6745 - val_accuracy: 0.6713
# Epoch 4/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0
100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4615 - accuracy: 0.8155 - val_loss: 0.4944 - val_accuracy: 0.8112
# Epoch 39/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.5018 - accuracy: 0.8155 - val_loss: 0.5068 - val_accuracy: 0.8182
# Epoch 40/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4562 - accuracy: 0.8207 - val_loss: 0.4635 - val_accuracy: 0.8042
# Epoch 41/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4600 - accuracy: 0.8190 - val_loss: 0.5112 - val_accuracy: 0.8182
# Epoch 42/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4516 - accuracy: 0.8049 - val_loss: 0.5583 - val_accuracy: 0.8112
# Epoch 43/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4562 - accuracy: 0.8172 - val_loss: 0.5151 - val_accuracy: 0.8112
# Epoch 44/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4567 - accuracy: 0.8225 - val_loss: 0.4710 - val_accuracy: 0.8112
# Epoch 45/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4727 - accuracy: 0.8084 - val_loss: 0.4710 - val_accuracy: 0.8182
# Epoch 46/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4554 - accuracy: 0.8243 - val_loss: 0.5043 - val_accuracy: 0.8182
# Epoch 47/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4305 - accuracy: 0.8190 - val_loss: 0.5462 - val_accuracy: 0.7762
# Epoch 48/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.5066 - accuracy: 0.8032 - val_loss: 0.5013 - val_accuracy: 0.8112
# Epoch 49/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4355 - accuracy: 0.8295 - val_loss: 0.4944 - val_accuracy: 0.8112
# Epoch 50/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4664 - accuracy: 0.8155 - val_loss: 0.4778 - val_accuracy: 0.8182
# Epoch 51/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4212 - accuracy: 0.8295 - val_loss: 0.5720 - val_accuracy: 0.8112
# Epoch 52/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4487 - accuracy: 0.8313 - val_loss: 0.4620 - val_accuracy: 0.8112
# Epoch 53/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4336 - accuracy: 0.8207 - val_loss: 0.5404 - val_accuracy: 0.8182
# Epoch 54/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4622 - accuracy: 0.8243 - val_loss: 0.5478 - val_accuracy: 0.7972
# Epoch 55/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4290 - accuracy: 0.8278 - val_loss: 0.5368 - val_accuracy: 0.8112
# Epoch 56/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4447 - accuracy: 0.8260 - val_loss: 0.5655 - val_accuracy: 0.7972
# Epoch 57/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4255 - accuracy: 0.8313 - val_loss: 0.4814 - val_accuracy: 0.8112
# Epoch 58/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4116 - accuracy: 0.8190 - val_loss: 0.5858 - val_accuracy: 0.7692
# Epoch 59/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4209 - accuracy: 0.8348 - val_loss: 0.5146 - val_accuracy: 0.8042
# Epoch 60/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4314 - accuracy: 0.8278 - val_loss: 0.5629 - val_accuracy: 0.8112
# Epoch 61/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4117 - accuracy: 0.8207 - val_loss: 0.5481 - val_accuracy: 0.8182
# Epoch 62/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4377 - accuracy: 0.8278 - val_loss: 0.6927 - val_accuracy: 0.8112
# Epoch 63/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4185 - accuracy: 0.8295 - val_loss: 0.5976 - val_accuracy: 0.7832
# Epoch 64/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4679 - accuracy: 0.8102 - val_loss: 0.5781 - val_accuracy: 0.7832
# Epoch 65/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4334 - accuracy: 0.8014 - val_loss: 0.6915 - val_accuracy: 0.8182
# Epoch 66/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4801 - accuracy: 0.8348 - val_loss: 0.5281 - val_accuracy: 0.8252
# Epoch 67/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4442 - accuracy: 0.8313 - val_loss: 0.5453 - val_accuracy: 0.8042
# Epoch 68/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4192 - accuracy: 0.8260 - val_loss: 0.5883 - val_accuracy: 0.8182
# Epoch 69/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.3935 - accuracy: 0.8453 - val_loss: 0.7310 - val_accuracy: 0.8112
# Epoch 70/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4211 - accuracy: 0.8366 - val_loss: 0.8073 - val_accuracy: 0.8182
# Epoch 71/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4433 - accuracy: 0.8155 - val_loss: 0.5513 - val_accuracy: 0.7832
# Epoch 72/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4141 - accuracy: 0.8330 - val_loss: 0.5780 - val_accuracy: 0.8182
# Epoch 73/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8313 - val_loss: 0.6669 - val_accuracy: 0.7972
# Epoch 74/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4195 - accuracy: 0.8366 - val_loss: 0.5085 - val_accuracy: 0.8182
# Epoch 75/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4213 - accuracy: 0.8348 - val_loss: 0.5715 - val_accuracy: 0.8112
# Epoch 76/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.3935 - accuracy: 0.8313 - val_loss: 0.6664 - val_accuracy: 0.8182
# Epoch 77/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4383 - accuracy: 0.8243 - val_loss: 0.7294 - val_accuracy: 0.8182
# Epoch 78/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4360 - accuracy: 0.8172 - val_loss: 0.7369 - val_accuracy: 0.8182
# Epoch 79/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4359 - accuracy: 0.8313 - val_loss: 0.7485 - val_accuracy: 0.7832
# Epoch 80/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.3867 - accuracy: 0.8330 - val_loss: 0.7049 - val_accuracy: 0.8252
# Epoch 81/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4104 - accuracy: 0.8383 - val_loss: 0.8811 - val_accuracy: 0.8252
# Epoch 82/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4163 - accuracy: 0.8383 - val_loss: 0.8399 - val_accuracy: 0.8112
# Epoch 83/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.3997 - accuracy: 0.8401 - val_loss: 0.7350 - val_accuracy: 0.8042
# Epoch 84/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4213 - accuracy: 0.8207 - val_loss: 0.6138 - val_accuracy: 0.8042
# Epoch 85/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4030 - accuracy: 0.8313 - val_loss: 0.6709 - val_accuracy: 0.7972
# Epoch 86/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4145 - accuracy: 0.8330 - val_loss: 0.6369 - val_accuracy: 0.8112
# Epoch 87/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.3971 - accuracy: 0.8366 - val_loss: 0.7389 - val_accuracy: 0.8112
# Epoch 88/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4135 - accuracy: 0.8348 - val_loss: 0.7324 - val_accuracy: 0.8112
# Epoch 89/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4125 - accuracy: 0.8172 - val_loss: 0.7970 - val_accuracy: 0.7832
# Epoch 90/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.3825 - accuracy: 0.8260 - val_loss: 0.9704 - val_accuracy: 0.8112
# Epoch 91/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4155 - accuracy: 0.8366 - val_loss: 0.9724 - val_accuracy: 0.8252
# Epoch 92/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.3959 - accuracy: 0.8348 - val_loss: 0.8412 - val_accuracy: 0.8252
# Epoch 93/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4314 - accuracy: 0.8278 - val_loss: 0.8597 - val_accuracy: 0.8182
# Epoch 94/100
# 569/569 [==============================] - 1s 1ms/step - loss: 0.4152 - accuracy: 0.8401 - val_loss: 0.7182 - val_accuracy: 0.7762
# Epoch 95/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.3988 - accuracy: 0.8260 - val_loss: 0.9108 - val_accuracy: 0.7832
# Epoch 96/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.3896 - accuracy: 0.8401 - val_loss: 0.9524 - val_accuracy: 0.8112
# Epoch 97/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4126 - accuracy: 0.8155 - val_loss: 0.8766 - val_accuracy: 0.8252
# Epoch 98/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.3930 - accuracy: 0.8313 - val_loss: 0.9330 - val_accuracy: 0.7902
# Epoch 99/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.4392 - accuracy: 0.8225 - val_loss: 0.5923 - val_accuracy: 0.8182
# Epoch 100/100
# 569/569 [==============================] - 1s 2ms/step - loss: 0.3936 - accuracy: 0.8436 - val_loss: 0.6655 - val_accuracy: 0.8182

# %%
plt.plot(history.history['val_accuracy'])
